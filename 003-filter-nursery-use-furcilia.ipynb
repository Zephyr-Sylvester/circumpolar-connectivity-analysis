# %% [markdown]
# # Step 3 - filter processed trajectories:
# Input: data from step 2
#
# Filter for when there are 21 days spent in a location as “used”
# export
# Output:  'processed_trajectories_21dfilter.csv'
#
# This step reduces the number of drifters from 1583 to 996

# %%
import xarray as xr
import pandas as pd
from datetime import datetime, timedelta
import os

from shapely.geometry import Point, Polygon as ShapelyPolygon
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# File Paths to data
repo_path = '/Users/zephyrsylvester/repos/circumpolar-connectivity-analysis/data/'
output_path = '/Users/zephyrsylvester/repos/circumpolar-connectivity-analysis/processed_data/'

# List of simulations and locations
locations = ['BS', 'GERL', 'GP', 'MB2']

# %%
file = output_path + 'processed_trajectories_wpresence_unfiltered.csv'
processed_df=pd.read_csv(file) 
print('raw number of larvae:', processed_df.larval_id.nunique())
processed_df
# Out:
# raw number of larvae: 16658
#            N    T        date        lat        lon  release  stage  \
# 0          0    0  2016-11-01 -66.912544  287.83374        0      0
# 1          0    1  2016-11-02 -66.830450  288.03165        0      0
# 2          0    2  2016-11-03 -66.757600  288.15454        0      0
# 3          0    3  2016-11-04 -66.711136  288.16013        0      0
# 4          0    4  2016-11-05 -66.718590  288.06876        0      0
# ...      ...  ...         ...        ...        ...      ...    ...
# 2998435  199  175  2019-09-12 -60.327457  306.02032       10      4
# 2998436  199  176  2019-09-13 -60.238560  305.90730       10      4
# 2998437  199  177  2019-09-14 -60.116886  305.83090       10      4
# 2998438  199  178  2019-09-15 -60.023293  305.82330       10      4
# 2998439  199  179  2019-09-16 -60.084550  305.71774       10      4
#
#             larval_id  start_year hypothesis IDL_loc     BS   GERL     GP  \
# 0        00_16_1_0001        2016     h_null      BS  False  False  False
# 1        00_16_1_0001        2016     h_null      BS  False  False  False
# 2        00_16_1_0001        2016     h_null      BS  False  False  False
# 3        00_16_1_0001        2016     h_null      BS  False  False  False
# 4        00_16_1_0001        2016     h_null      BS  False  False  False
# ...               ...         ...        ...     ...    ...    ...    ...
# 2998435  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998436  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998437  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998438  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998439  00_18_1_0200        2018     h_null      BS  False  False  False
#
#            MB2  outside
# 0        False     True
# 1        False     True
# 2        False     True
# 3        False     True
# 4        False     True
# ...        ...      ...
# 2998435  False     True
# 2998436  False     True
# 2998437  False     True
# 2998438  False     True
# 2998439  False     True
#
# [2998440 rows x 16 columns]

# %% [markdown]
# # Filter to 21 days in locs

# %%
# Define the presence columns
presence_columns = ['BS', 'GERL', 'GP', 'MB2','outside']

# Group by hypothesis, start year, IDL_loc, and larval_id, and sum the presence counts
grouped_df = processed_df.groupby(['hypothesis', 'start_year', 'IDL_loc', 'larval_id'])[presence_columns].sum().reset_index()

print('number of larvae:', grouped_df.larval_id.nunique())

grouped_df
# Out:
# number of larvae: 16658
#       hypothesis  start_year IDL_loc     larval_id   BS  GERL  GP  MB2  \
# 0          h_dvm        2016      BS  02_16_1_0001   28     0   0    0
# 1          h_dvm        2016      BS  02_16_1_0002   13     0   0    0
# 2          h_dvm        2016      BS  02_16_1_0003   47    52   0    0
# 3          h_dvm        2016      BS  02_16_1_0004   33     0   0    0
# 4          h_dvm        2016      BS  02_16_1_0005  102     0   0    0
# ...          ...         ...     ...           ...  ...   ...  ..  ...
# 16653     h_size        2018     MB2  03_18_4_1071    0     0  31   58
# 16654     h_size        2018     MB2  03_18_4_1072    0     0  81   87
# 16655     h_size        2018     MB2  03_18_4_1073    0     0  69  102
# 16656     h_size        2018     MB2  03_18_4_1074    0     0  39   82
# 16657     h_size        2018     MB2  03_18_4_1075    0     0  75   50
#
#        outside
# 0          152
# 1          167
# 2           81
# 3          147
# 4           78
# ...        ...
# 16653       91
# 16654       12
# 16655        9
# 16656       59
# 16657       55
#
# [16658 rows x 9 columns]

# %%
# Initialize an empty DataFrame to collect the filtered results
filtered_results = pd.DataFrame()

# Filter for each presence column where the IDL_loc matches the column name and the count is greater than 21
for col in presence_columns:
    presence_columns = ['BS', 'GERL', 'GP', 'MB2']
    filtered = grouped_df[(grouped_df['IDL_loc'] == col) & (grouped_df[col] > 21)]
    filtered_results = pd.concat([filtered_results, filtered])

# Extract the unique larval_id's from the filtered results
filtered_larval_ids = filtered_results['larval_id'].unique()

# Create a subset of processed_df containing only the filtered larval_id's
df_21 = processed_df[processed_df['larval_id'].isin(filtered_larval_ids)]
print('number of larvae:', df_21.larval_id.nunique())
df_21
# Out:
# number of larvae: 11487
#            N    T        date        lat        lon  release  stage  \
# 360        2    0  2016-11-01 -63.602314  298.26752        0      0
# 361        2    1  2016-11-02 -63.569042  298.23145        0      0
# 362        2    2  2016-11-03 -63.522503  298.25543        0      0
# 363        2    3  2016-11-04 -63.483067  298.28790        0      0
# 364        2    4  2016-11-05 -63.438553  298.33795        0      0
# ...      ...  ...         ...        ...        ...      ...    ...
# 2998255  198  175  2019-09-12 -61.923122  299.13315       10      4
# 2998256  198  176  2019-09-13 -61.860650  299.25064       10      4
# 2998257  198  177  2019-09-14 -61.813430  299.41430       10      4
# 2998258  198  178  2019-09-15 -61.756500  299.58655       10      4
# 2998259  198  179  2019-09-16 -61.720387  299.79540       10      4
#
#             larval_id  start_year hypothesis IDL_loc     BS   GERL     GP  \
# 360      00_16_1_0003        2016     h_null      BS   True  False  False
# 361      00_16_1_0003        2016     h_null      BS   True  False  False
# 362      00_16_1_0003        2016     h_null      BS   True  False  False
# 363      00_16_1_0003        2016     h_null      BS   True  False  False
# 364      00_16_1_0003        2016     h_null      BS   True  False  False
# ...               ...         ...        ...     ...    ...    ...    ...
# 2998255  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998256  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998257  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998258  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998259  00_18_1_0199        2018     h_null      BS  False  False  False
#
#            MB2  outside
# 360      False    False
# 361      False    False
# 362      False    False
# 363      False    False
# 364      False    False
# ...        ...      ...
# 2998255  False     True
# 2998256  False     True
# 2998257  False     True
# 2998258  False     True
# 2998259  False     True
#
# [2067660 rows x 16 columns]

# %%
# Export
output_file = os.path.join(output_path, 'processed_trajectories_21dfilter.csv')
df_21.to_csv(output_file, index=False)

# %% [markdown]
# # Filter Filtered Data for Furcilia Only

# %%
# Pre-processing function
def preprocess_data(df, stages):
    stage_df = df[df['stage'].isin(stages)].copy()
    return stage_df

stages = [3,4]

df21_furfilter = preprocess_data(df_21, stages)
print('number of larvae:', df21_furfilter.larval_id.nunique())
df21_furfilter
# Out:
# number of larvae: 11487
#            N    T        date        lat        lon  release  stage  \
# 421        2   61  2017-01-01 -63.573807  298.18576        0      3
# 422        2   62  2017-01-02 -63.510464  298.16113        0      3
# 423        2   63  2017-01-03 -63.472840  298.16586        0      3
# 424        2   64  2017-01-04 -63.449047  298.17532        0      3
# 425        2   65  2017-01-05 -63.421852  298.19568        0      3
# ...      ...  ...         ...        ...        ...      ...    ...
# 2998255  198  175  2019-09-12 -61.923122  299.13315       10      4
# 2998256  198  176  2019-09-13 -61.860650  299.25064       10      4
# 2998257  198  177  2019-09-14 -61.813430  299.41430       10      4
# 2998258  198  178  2019-09-15 -61.756500  299.58655       10      4
# 2998259  198  179  2019-09-16 -61.720387  299.79540       10      4
#
#             larval_id  start_year hypothesis IDL_loc     BS   GERL     GP  \
# 421      00_16_1_0003        2016     h_null      BS   True  False  False
# 422      00_16_1_0003        2016     h_null      BS   True  False  False
# 423      00_16_1_0003        2016     h_null      BS   True  False  False
# 424      00_16_1_0003        2016     h_null      BS   True  False  False
# 425      00_16_1_0003        2016     h_null      BS   True  False  False
# ...               ...         ...        ...     ...    ...    ...    ...
# 2998255  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998256  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998257  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998258  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998259  00_18_1_0199        2018     h_null      BS  False  False  False
#
#            MB2  outside
# 421      False    False
# 422      False    False
# 423      False    False
# 424      False    False
# 425      False    False
# ...        ...      ...
# 2998255  False     True
# 2998256  False     True
# 2998257  False     True
# 2998258  False     True
# 2998259  False     True
#
# [1366953 rows x 16 columns]

# %%
# Export
output_file = os.path.join(output_path, 'processed_trajectories_21d_filter_fur_filter.csv')
df21_furfilter.to_csv(output_file, index=False)

# %% [markdown]
# # Filter for furcilia use

# %%
# Pre-processing function
def furcilia_data(df, stages):
    stage_df = df[df['stage'].isin(stages)].copy()
    return stage_df

stages = [3,4]

df_fur = furcilia_data(processed_df, stages)
df_fur
# Out:
#            N    T        date        lat        lon  release  stage  \
# 61         0   61  2017-01-01 -63.868473  294.59207        0      3
# 62         0   62  2017-01-02 -63.834896  294.76250        0      3
# 63         0   63  2017-01-03 -63.763615  294.91858        0      3
# 64         0   64  2017-01-04 -63.713238  295.05530        0      3
# 65         0   65  2017-01-05 -63.685104  295.23840        0      3
# ...      ...  ...         ...        ...        ...      ...    ...
# 2998435  199  175  2019-09-12 -60.327457  306.02032       10      4
# 2998436  199  176  2019-09-13 -60.238560  305.90730       10      4
# 2998437  199  177  2019-09-14 -60.116886  305.83090       10      4
# 2998438  199  178  2019-09-15 -60.023293  305.82330       10      4
# 2998439  199  179  2019-09-16 -60.084550  305.71774       10      4
#
#             larval_id  start_year hypothesis IDL_loc     BS   GERL     GP  \
# 61       00_16_1_0001        2016     h_null      BS  False  False  False
# 62       00_16_1_0001        2016     h_null      BS  False  False  False
# 63       00_16_1_0001        2016     h_null      BS  False  False  False
# 64       00_16_1_0001        2016     h_null      BS  False  False  False
# 65       00_16_1_0001        2016     h_null      BS  False  False  False
# ...               ...         ...        ...     ...    ...    ...    ...
# 2998435  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998436  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998437  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998438  00_18_1_0200        2018     h_null      BS  False  False  False
# 2998439  00_18_1_0200        2018     h_null      BS  False  False  False
#
#            MB2  outside
# 61       False     True
# 62       False     True
# 63       False     True
# 64       False     True
# 65       False     True
# ...        ...      ...
# 2998435  False     True
# 2998436  False     True
# 2998437  False     True
# 2998438  False     True
# 2998439  False     True
#
# [1982302 rows x 16 columns]

# %%
# Define the presence columns
presence_columns = ['BS', 'GERL', 'GP', 'MB2','outside']

# Group by hypothesis, start year, IDL_loc, and larval_id, and sum the presence counts
grouped_df = df_fur.groupby(['hypothesis', 'start_year', 'IDL_loc', 'larval_id'])[presence_columns].sum().reset_index()

print('number of larvae:', grouped_df.larval_id.nunique())

grouped_df
# Out:
# number of larvae: 16658
#       hypothesis  start_year IDL_loc     larval_id   BS  GERL  GP  MB2  \
# 0          h_dvm        2016      BS  02_16_1_0001   28     0   0    0
# 1          h_dvm        2016      BS  02_16_1_0002   13     0   0    0
# 2          h_dvm        2016      BS  02_16_1_0003   47    52   0    0
# 3          h_dvm        2016      BS  02_16_1_0004   33     0   0    0
# 4          h_dvm        2016      BS  02_16_1_0005  102     0   0    0
# ...          ...         ...     ...           ...  ...   ...  ..  ...
# 16653     h_size        2018     MB2  03_18_4_1071    0     0   0   37
# 16654     h_size        2018     MB2  03_18_4_1072    0     0  20   87
# 16655     h_size        2018     MB2  03_18_4_1073    0     0   8  102
# 16656     h_size        2018     MB2  03_18_4_1074    0     0   0   79
# 16657     h_size        2018     MB2  03_18_4_1075    0     0  14   50
#
#        outside
# 0           91
# 1          106
# 2           20
# 3           86
# 4           17
# ...        ...
# 16653       82
# 16654       12
# 16655        9
# 16656       40
# 16657       55
#
# [16658 rows x 9 columns]

# %%
# Initialize an empty DataFrame to collect the filtered results
filtered_results = pd.DataFrame()

# Filter for each presence column where the IDL_loc matches the column name and the count is greater than 21
for col in presence_columns:
    presence_columns = ['BS', 'GERL', 'GP', 'MB2']
    filtered = grouped_df[(grouped_df['IDL_loc'] == col) & (grouped_df[col] > 21)]
    filtered_results = pd.concat([filtered_results, filtered])

# Extract the unique larval_id's from the filtered results
filtered_larval_ids = filtered_results['larval_id'].unique()

# Create a subset of processed_df containing only the filtered larval_id's
df_fur_21 = processed_df[processed_df['larval_id'].isin(filtered_larval_ids)]
print('number of larvae:', df_fur_21.larval_id.nunique())
df_fur_21
# Out:
# number of larvae: 8768
#            N    T        date        lat        lon  release  stage  \
# 360        2    0  2016-11-01 -63.602314  298.26752        0      0
# 361        2    1  2016-11-02 -63.569042  298.23145        0      0
# 362        2    2  2016-11-03 -63.522503  298.25543        0      0
# 363        2    3  2016-11-04 -63.483067  298.28790        0      0
# 364        2    4  2016-11-05 -63.438553  298.33795        0      0
# ...      ...  ...         ...        ...        ...      ...    ...
# 2998255  198  175  2019-09-12 -61.923122  299.13315       10      4
# 2998256  198  176  2019-09-13 -61.860650  299.25064       10      4
# 2998257  198  177  2019-09-14 -61.813430  299.41430       10      4
# 2998258  198  178  2019-09-15 -61.756500  299.58655       10      4
# 2998259  198  179  2019-09-16 -61.720387  299.79540       10      4
#
#             larval_id  start_year hypothesis IDL_loc     BS   GERL     GP  \
# 360      00_16_1_0003        2016     h_null      BS   True  False  False
# 361      00_16_1_0003        2016     h_null      BS   True  False  False
# 362      00_16_1_0003        2016     h_null      BS   True  False  False
# 363      00_16_1_0003        2016     h_null      BS   True  False  False
# 364      00_16_1_0003        2016     h_null      BS   True  False  False
# ...               ...         ...        ...     ...    ...    ...    ...
# 2998255  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998256  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998257  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998258  00_18_1_0199        2018     h_null      BS  False  False  False
# 2998259  00_18_1_0199        2018     h_null      BS  False  False  False
#
#            MB2  outside
# 360      False    False
# 361      False    False
# 362      False    False
# 363      False    False
# 364      False    False
# ...        ...      ...
# 2998255  False     True
# 2998256  False     True
# 2998257  False     True
# 2998258  False     True
# 2998259  False     True
#
# [1578240 rows x 16 columns]

# %%
# Export
output_file = os.path.join(output_path, 'processed_trajectories_furciliaonly-21dfilter.csv')
df_fur_21.to_csv(output_file, index=False)
